# %% [markdown]
# # 딥러닝
#
# - 인간이 문제를 해결하는 방식을 모방해서, 계속 데이터를 분석하고 그안에서 패턴을 찾아내려고 합니다.
# - 머신이 대화의 맥락을 이해하고, 사용자의 요청에 맞는 적절한 대답이나 조치를 취할 수 있도록합니다.

# %% [markdown]
# ## 머신러닝과 딥러닝의 차이
#
# - 딥러닝은 머신러닝의 한분야로 더 깊고 복잡한 학습을 가능하게 합니다.
# - 머신러닝은 컴퓨터가 데이터를 분석하고 그 안에서 학습을 하여 결정을 내리는 과정, 이 과정에서 뭔가 잘못되면 사람이 개입해서 수정해야 한다.
#     - 새로운 유형의 스팸이 등장할 때마다 사람이 이를 지도해야 한다.
# - `딥러닝`의 경우 패턴을 스스로 학습하고, 더 복잡하고 미묘한 스팸의 형태까지도 자동으로 식별, 인간의 개입 없이도 스스로 학습과 판단 능력을 갖춘 인공신경망을 통해 이루어진다.
#     - 입력 -> 특징 추출 -> 분류 알고리즘 -> 출력
# - `머신러닝`은 데이터로부터 배우는 컴퓨터의 능력 `딥러닝`은 이런 학습과정을 더욱 깊게 하여 스스로 판단하고 결정할 수 있는 능력을 가진 인공 신경망을 만드는 것
#     - 입력 -> 인공 신경망(특징 추출 & 분류 ) -> 출력

# %% [markdown]
# ## 머신러닝의 다양한 유형
#
# 1. 지도 학습
#
# - 입력 데이터와 그에 해당하는 정답(라벨)을 함께 제공받음
# - 데이터 과학자는 모델이 제시한 예측이 정확한지 평가하고, 모델을 조정하여 오류를 최소화 한다.
# - 지도 학습의 종류
#     - 분류(Classification) : 데이터를 사전에 정의된 여러 범주중 하나로 할당하는 과정
#     - 회귀(Regression): 연속적인 값을 예측하는 과정

# %% [markdown]
# 2. 비지도 학습
#
# - 모델에 정답 라벨이 붙어 있지 않은 데이터만 제공
# - 컴퓨터가 스스로 데이터 안에서 패턴이나 구조를 발견
# - 데이터에서 어떤 결과를 기대해야 할 지 명확하지 않을 때 유용
# - 비지도 학습의 종류
#     - 클러스터링 ( Clustering ) : 데이터를 자연스럽게 유사한 그룹으로 나누는 과정
#     - 차원 축소(Dimensionality Reduction) : 데이터의 특성을 줄이는 것을 목표, 데이터의 가장 중요한 특성을 유지하면서 노이즈를 제거하고 계산을 단순화하기 위해 사용 ( 예) PCA )

# %% [markdown]
# 3. 강화 학습
#
# - 자신의 행동에 대한 피드백을 받으며, 올바른 결정에는 보상을, 잘못된 결정에는 처벌을 받는다.

# %% [markdown]
# # 딥러닝 알고리즘

# %% [markdown]
# 1. 합성곱 신경망 (CNN)
#
# - 이미지 처리와 객체 인식에 탁월한 딥러닝 알고리즘입니다.
# - 사람이 이미지에서 모서리, 질감, 형태를 단계적으로 파악하듯이,
#   CNN도 낮은 수준 특징(선, 경계)부터 높은 수준 특징(얼굴, 자동차)까지 자동으로 학습합니다.
# - 핵심 구성:
#   - 합성곱(Convolution) 층: 중요한 특징을 추출
#   - 풀링(Pooling) 층: 정보는 유지하면서 크기를 줄여 계산량 감소
#   - 완전연결(Fully Connected) 층: 최종 분류 수행
#
# 예시:
# - 고양이/강아지 사진 분류
# - 의료 영상(X-ray)에서 이상 부위 탐지
# - 자율주행에서 보행자/차선 인식
#
# 간단한 동작 흐름:
# - 입력 이미지 -> 특징 추출(합성곱) -> 크기 축소(풀링) -> 분류 결과 출력
#
# 2. 순환 신경망 (RNN)
#
# - 시간에 따른 데이터의 순서와 연관성을 학습하는 데 강점을 가진 알고리즘입니다.
# - 일반 신경망과 달리 이전 시점의 정보를 다음 계산에 반영하여,
#   "순서"가 중요한 데이터를 다루는 데 유리합니다.
# - 핵심 아이디어:
#   - 현재 입력 + 이전 상태(hidden state)를 함께 사용
#   - 과거 문맥을 이어받아 다음 값을 예측
#
# 예시:
# - 문장 다음 단어 예측 (자연어 처리)
# - 주가/전력 사용량 같은 시계열 예측
# - 음성 인식, 번역, 감성 분석
#
# 간단한 동작 흐름:
# - t시점 입력 + t-1 시점 기억 -> t시점 출력 생성 -> 다음 시점으로 기억 전달
#
# 참고:
# - 긴 시퀀스에서는 기본 RNN이 장기 의존성 학습이 어렵기 때문에,
#   실무에서는 LSTM, GRU를 자주 사용합니다.

# %% [markdown]
# ## 딥러닝
#
# 1. 퍼셉트론
#
# - 퍼셉트론은 인공 신경망 모델 중 가장 기본적인 형태
# - 1957년 로젠블라트(Frank Rosenblatt)에 의해 개발 되었다.

# %% [markdown]
# ## 가중치와 편향
#
# 1. 가중치(Weight)
#
# - 입력 신호가 출력에 미치는 영향력을 조절
# - 중요성이나 영향을 나타냄
# - 훈련을 통해 최적화 된다.
#
# 2. 편향(Bias)
#
# - 퍼셉트론에서는 결정을 내리는 기준점으로 임계값(세타 $\theta$ ) 를 사용
# - 이 값을 넘어설 때 만 퍼셉트론이 1을 출력
# - 임계값($\theta$)를 $-b$ 로 치환하여 편향 b를 사용합니다.
#     - 편향은 결정 임계값을 조정하는 역할
# - 편향은 가중치들과 함께 조절되어야하는 중요한 파라미터
# - $w1x1 + w2x2 + b(편향) = y$
#
# - 가중치는 입력 신호의 중요도를 조정하는 반면, 편향은 모델이 어느 정도 확실을 갖고 결정을 내릴 수 있도록 해준다.

# %% [markdown]
# # 단층 퍼셉트론과 다층 퍼셉트론
#
# ## 퍼셉트론의 종류
#
# - 단층(단일층) 퍼셉트론과 다층 퍼셉트론으로 나뉜다.
#
# ### 한계
#
# - 선형 분리가 가능한 문제에 대해서만 효과적으로 작동
# - 데이터가 선형으로 분리 될 수 있는 경우에만 클래스를 정확하게 구분할 수 있다.

# %% [markdown]
# ## 다층 퍼셉트론, 단층 퍼셉트론 한계 극복
#
# - Multi-layer perceptron, MLP
# - 여러개의 층(layer)
# - 비선형 문제를 해결 할 수 있는 능력을 가지게 됨.
# - 하나 이상의 은닉층을 포함

# %% [markdown]
# ### 활성화 함수(activation function)
#
# #### 인공 신경망의 기본 구조
#
# - 인공 신경망의 기본 구조
# - 신경망 안의 노드가 받은 신호를 가지고, 다음 단계로 어떤 신호를 보낼지 결정하게 해준다.
# - 노드가 얼마나 `활성화` 될지를 결정하는 것.
# - 만약 입력 신호가 중요하다면, 활성화 함수는 노드를 활성화시켜 다음 레벨로 강한 신호를 보내게 할 거고, 그렇지 않다면 신호를 약하게 만들거나 전혀 보내지 않을 것.
# - 이런 활성화 함수는 신경망이 단순한 직선적인 관계만이 아닌, 곡선이나 더 복잡한 형태의 관계를 배울 수 있게 도와준다.

# %% [markdown]
# $$
# w1x1 + w2x2 + b = a(가중합)
# $$
#
# $$
# h(a) = y
# $$

# %% [markdown]
# # 계단 함수(step function)의 이해
#
# - 기본적인 활성화 함수 중 하나인 계단 함수는 이름처럼 계단 모양을 하고 있다.
# - 입력값이 특정 임계값보다 크거나 작을 때 두가지의 고유한 값(0 or 1) 중 하나를 출력하는 함수
#
# ## 장단점
#
# - 구현이 매우 간단, 이해하기 쉽다.
# - 그라디언트(미분값) 0이 되기 때문에, 역전파에서 가중치를 업데이트할 때 사용할 수 없다. 이로인해 심층(깊은 신경망) 학습에는 적합하지 않음.
# - 특정 값에 따라 0 또는 1의 출력값을 가지며, 비선형 함수

# %% [markdown]
# $$f(x) = \begin{cases} 0 & (x \le \theta) \\ 1 & (x > \theta) \end{cases}$$

# %% [markdown]
# ## 활성화 함수의 유형 및 종류
#
# - 시그모이드(sigmoid) : 출력이 0과 1사이 이진분류 문제에서 출력층에 주로 사용. 그라디언트 소실 문제가 있을 수 있다.
# - 탄젠트(Tanh): 출력이 -1과 1 사이. 중심이 0에 가까워 학습 초기에 유리할 수 있지만, 그라디언트 소실 문제가 있다.
# - 렐루(ReLU): 음수 입력에 대해서는 0, 양수 입력에 대해서는 입력을 그대로 출력, 학습 속도가 빠르며, 일반적으로 은닉층에 사용
# - Softmax(소프트맥스): 다중 클래스 분류 문제의 출력층에 사용, 출력값을 확률 분포로 반환

# %%
import numpy as np
import matplotlib.pyplot as plt

# 시그모이드 함수
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# 시그모이드 미분
def sigmoid_derivative(x):
    s = sigmoid(x)
    return s * (1 - s)

# x 범위
x = np.linspace(-10, 10, 500)

# y 계산
y_sigmoid = sigmoid(x)
y_derivative = sigmoid_derivative(x)

# 그래프
plt.figure(figsize=(10, 5))
plt.plot(x, y_sigmoid, label='Sigmoid: σ(x)', linewidth=2)
plt.plot(x, y_derivative, label="Derivative: σ'(x)", linewidth=2, linestyle='--')
plt.title('Sigmoid Function and Its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='gray', linewidth=0.8)
plt.axvline(0, color='gray', linewidth=0.8)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}
# $$
#
# $$
# \sigma'(x) = \sigma(x)\left(1-\sigma(x)\right)
# $$

# %% [markdown]
# ## 시그모이드 미분 공식 유도
#
# 시그모이드 함수를 다음과 같이 둡니다.
#
# $$
# \sigma(x) = \frac{1}{1+e^{-x}} = (1+e^{-x})^{-1}
# $$
#
# 양변을 $x$에 대해 미분하면,
#
# $$
# \sigma'(x) = \frac{d}{dx}(1+e^{-x})^{-1}
# $$
#
# 연쇄법칙을 적용하면,
#
# $$
# \sigma'(x) = -(1+e^{-x})^{-2} \cdot \frac{d}{dx}(1+e^{-x})
# $$
#
# 그리고
#
# $$
# \frac{d}{dx}(1+e^{-x}) = -e^{-x}
# $$
#
# 이므로,
#
# $$
# \sigma'(x) = -(1+e^{-x})^{-2}(-e^{-x})
# = \frac{e^{-x}}{(1+e^{-x})^2}
# $$
#
# 이 식을 시그모이드 형태로 다시 쓰면,
#
# $$
# \sigma(x)=\frac{1}{1+e^{-x}}, \quad
# 1-\sigma(x)=1-\frac{1}{1+e^{-x}}=\frac{e^{-x}}{1+e^{-x}}
# $$
#
# 따라서,
#
# $$
# \sigma(x)(1-\sigma(x))
# = \frac{1}{1+e^{-x}} \cdot \frac{e^{-x}}{1+e^{-x}}
# = \frac{e^{-x}}{(1+e^{-x})^2}
# = \sigma'(x)
# $$
#
# 최종 결과:
#
# $$
# \boxed{\sigma'(x) = \sigma(x)(1-\sigma(x))}
# $$

# %% [markdown]
# ## 기울기 소실
#
# - 기울기 소실은 신경망 학습의 효율성을 크게 저하시킨다.
#
# ### 기울기 소실의 해결방안
#
# - 기울기 소실 문제에 대한 효과적인 해결책 중 하나는 `ReLU(Rectified Linear Unit)`함수나 그 변형들을 사용하는 것
# - 이 활성화 함수들은 미분값이 0으로 떨어지지 않게 해줌으로써, 기울기 소실 문제를 크게 완화 시킬 수 있다.

# %% [markdown]
# ## 시그모이드 함수의 활용성과 한계
#
# ### 장점
#
# - 출력이 항상 0과 1사이
# - 출력을 확률로 쉽게 해석할 수 있다. ( 가능성을 0~1사이 값으로 나타낼 수 있다.)
# - 미분 값이 양수 ( 가중치를 업데이트 하는 방향이 항상 일정, 학습 과정 중에 `방향성`이 뒤바뀌지 않아서, 학습이 더욱 안정적으로 진행  )
#
# ### 단점
#
# - 그래디언트 소실 ( 미분값이 점점 작아지는 문제 )
# - 역전파 과정에서 가중치를 조정하는데 필요한 그래디언트가 충분히 전달되지 않을 수 있다.
# - 시그모이드 함수의 출력이 항상 양수 -> 모든 뉴런의 활성화가 항상 양의 방향으로만 이루어진다는 것을 의미, 이로 인해 학습 과정이 불균형해 질 수 있다.
# - 신경망의 다양한 층에서는 값들이 0을 중심으로 분포하지 않게 되어, 이른바 `중심이 이동하는`문제가 발생

# %%
import torch 

torch_data = torch.tensor([-1.0, 0.0, 1.0])
sigmoid_torch_result = torch.sigmoid(torch_data)

print(sigmoid_torch_result)  # tensor([0.2689, 0.5000, 0.7311])
# Out:
# tensor([0.2689, 0.5000, 0.7311])

# %%
import torch 
import torch.nn as nn

linear_layer = nn.Linear(in_features=2, out_features=1) #선형층 정의 ( 입력 특성 2개, 출력 특성 1개 )

# %% [markdown]
# - 2개의 입력 특성을 받아서 1개의 출력 특성을 생성하는 선형 레이어를 정의
#
# $ output = input * weight + bias $ 형태의 선형 변환을 적용

# %%
# 임의의 입력 텐서 생성 (배치 크기 1, 입력 특성 2개)
input_tensor = torch.randn(1, 2) #정규 분포를 이용하여 (1,2)형태의 랜덤 텐서를 생성 
print("랜덤으로 생성한 입력 텐서:\n", input_tensor)
# 배치 크기가 1이고 2개의 입력 특성을 가진 단일 데이터 샘플
# Out:
# 랜덤으로 생성한 입력 텐서:
#  tensor([[ 0.2218, -1.0130]])

# %% [markdown]
# # 배치크기 의미
# 여기서 배치크기는 한 번의 순전파에서 모델에 동시에 넣는 데이터 샘플 개수입니다.
#
# 현재 입력 텐서 모양이 (1, 2)이므로:
# - 1: 배치크기(샘플 1개)
# - 2: 각 샘플의 입력 특성 수(in_features=2)
#
# 즉, 지금 코드는 샘플 1개를 넣어 테스트하는 상태입니다.
# 만약 (32, 2)라면 한 번에 32개 샘플을 같이 학습/추론하는 뜻입니다.
#
# ### 추가 자료
# - [PyTorch Tensor Shapes](https://pytorch.org/docs/stable/tensors.html)
# - [Mini-batch Gradient Descent](https://en.wikipedia.org/wiki/Stochastic_gradient_descent)

# %%
# 선형 층을 통과
linear_output = linear_layer(input_tensor)
print("\n선형(Linear) 레이어 출력:\n", linear_output)
# Out:
# 선형(Linear) 레이어 출력:
#  tensor([[0.3916]], grad_fn=<AddmmBackward0>)

# %%
# 시그모이드 활성화 함수 적용
sigmoid_output = torch.sigmoid(linear_output)
print("\n시그모이드(Sigmoid) 출력:\n", sigmoid_output)
# Out:
# 시그모이드(Sigmoid) 출력:
#  tensor([[0.5967]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# ## 하이퍼볼릭 탄젠트(Tanh)

# %% [markdown]
# $$f(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}}$$
#
# $$f'(x) = 1 - (f(x))^2$$

# %% [markdown]
# - 신경망의 입력을 ㅂ다아 -1과 1사이의 값으로 압축하여 출력함으로써, 데이터의 스케일을 조정하고 중심을 0 주위로 맞춤
# - 이런 특성은 모델의 학습 과정에서 매우 유리한 효과를 가져다 주며, 신경망이 더욱 효과적으로 가중치를 조절하게 한다.
# - 신경망의 은닉층에서 자주 볼 수 있다.
# - 출력을 -1과 1사이로 조정함으로써, 데이터가 0을 중심으로 분포하게 되어 학습 과정을 안정시키고 가속화 하기 때문.

# %%
import numpy as np
import matplotlib.pyplot as plt

# tanh 함수와 미분 함수
def tanh(x):
    return np.tanh(x)

def tanh_derivative(x):
    y = tanh(x)
    return 1 - y**2

# x 범위
x = np.linspace(-6, 6, 500)

# y 계산
y_tanh = tanh(x)
y_dtanh = tanh_derivative(x)

# 그래프
plt.figure(figsize=(10, 5))
plt.plot(x, y_tanh, label='tanh(x)', linewidth=2)
plt.plot(x, y_dtanh, '--', label="tanh'(x) = 1 - tanh^2(x)", linewidth=2)

plt.title('Hyperbolic Tangent and Its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='gray', linewidth=0.8)
plt.axvline(0, color='gray', linewidth=0.8)
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# - $x=0$근처에서 미분의 최대 값을 가진다
#
# ## 장점
#
# - 출력의 중심이 0이므로 학습이 더 안정적이고 빠르다.
# - 학습 과정에서의 발산 문제를 줄여준다.
# - Sigmoid 함수에 비해 기울기 소실 문제를 다소 완화합니다.
# - 대칭성 때문에 네트워크 초기 학습에서 더 나은 성능을 보일 수 있다.
#
# ## 단점
#
# - 여전히 깊은 신경망에서는 기울기 소실 문제가 발생할 수 있다.
# - ReLU와 같은 다른 활성화 함수에 비해 계산이 복잡하다.
# - 포화 문제로 인해 학습이 느려질 수 있다.
#     - 입력값의 절대값이 큰 경우 Tanh 함수의 기울기가 매우작아져서 학습이 느려질 수 있다.

# %%
torch_data = torch.tensor([-1.0, 0.0, 1.0])
tanh_result = torch.tanh(torch_data)

print(tanh_result)
# Out:
# tensor([-0.7616,  0.0000,  0.7616])

# %%
# 선형 층 정의 (입력 특성 3개, 출력 특성 1개)
linear_layer = nn.Linear(in_features=3, out_features=1)

# 임의의 입력 텐서 생성 (배치 크기 1, 입력 특성 3개)
input_tensor = torch.randn(1, 3)
print("Input Tensor:\n", input_tensor)

# 선형 층을 통과
linear_output = linear_layer(input_tensor)
print("\nLinear Layer Output:\n", linear_output)

# 하이퍼볼릭 탄젠트 활성화 함수 적용
tanh_output = torch.tanh(linear_output)
print("\nTanh Output:\n", tanh_output)
# Out:
# Input Tensor:
#  tensor([[0.6804, 0.2375, 0.4775]])
#
# Linear Layer Output:
#  tensor([[-0.5996]], grad_fn=<AddmmBackward0>)
#
# Tanh Output:
#  Ellipsis
